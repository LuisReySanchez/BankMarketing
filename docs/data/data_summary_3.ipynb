# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reporte de Datos
#
# Este documento contiene los resultados del análisis exploratorio de datos.

# %%
df = pd.read_csv('/content/drive/MyDrive/Machine Learning & Data Science Avanzado/Proyecto aplicado/bank-additional-full.csv', sep=';')
df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %% [markdown]
# ## Resumen general de los datos
#
# En esta sección se presenta un resumen general de los datos. Se describe el número total de observaciones, variables, el tipo de variables, la presencia de valores faltantes y la distribución de las variables.
#
# El dataset que se eligio contiene un total de 41188 registros y  20 columnas con las variables independientes mas la columna que representa la variable a predecir, en total serian 21 columnas.

# %% [markdown]
# ## Resumen de calidad de los datos
#
# En esta sección se presenta un resumen de la calidad de los datos. Se describe la cantidad y porcentaje de valores faltantes, valores extremos, errores y duplicados. También se muestran las acciones tomadas para abordar estos problemas.

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 12

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41176 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41176 non-null  int64
#  1   job             41176 non-null  object
#  2   marital         41176 non-null  object
#  3   education       41176 non-null  object
#  4   default         41176 non-null  object
#  5   housing         41176 non-null  object
#  6   loan            41176 non-null  object
#  7   contact         41176 non-null  object
#  8   month           41176 non-null  object
#  9   day_of_week     41176 non-null  object
#  10  duration        41176 non-null  int64
#  11  campaign        41176 non-null  int64
#  12  pdays           41176 non-null  int64
#  13  previous        41176 non-null  int64
#  14  poutcome        41176 non-null  object
#  15  emp.var.rate    41176 non-null  float64
#  16  cons.price.idx  41176 non-null  float64
# ...

# %%
df.describe().T
# Out:
#                   count         mean         std       min       25%  \
# age             41176.0    40.023800   10.420680    17.000    32.000
# duration        41176.0   258.315815  259.305321     0.000   102.000
# campaign        41176.0     2.567879    2.770318     1.000     1.000
# pdays           41176.0   962.464810  186.937102     0.000   999.000
# previous        41176.0     0.173013    0.494964     0.000     0.000
# emp.var.rate    41176.0     0.081922    1.570883    -3.400    -1.800
# cons.price.idx  41176.0    93.575720    0.578839    92.201    93.075
# cons.conf.idx   41176.0   -40.502863    4.627860   -50.800   -42.700
# euribor3m       41176.0     3.621293    1.734437     0.634     1.344
# nr.employed     41176.0  5167.034870   72.251364  4963.600  5099.100
#
#                      50%       75%       max
# age               38.000    47.000    98.000
# duration         180.000   319.000  4918.000
# campaign           2.000     3.000    56.000
# ...

# %% [markdown]
# Se presentaron registros dupllicados para los cuales se tomó la opcion de removerlos

# %% [markdown]
# ## Variable objetivo
#
# En esta sección se describe la variable objetivo. Se muestra la distribución de la variable y se presentan gráficos que permiten entender mejor su comportamiento.

# %%
plt.bar(df['y'].value_counts().index, df['y'].value_counts().values)
plt.title('Distribución de la variable objetivo')
plt.show()

# %% [markdown]
# Con la anterior grafica se puede observar que estamos tratando con un dataset desbalanceado. Se realizarán tecnicas de balanceo como under-sampling y over-sampling

# %% [markdown]
# ## Variables individuales
#
# En esta sección se presenta un análisis detallado de cada variable individual. Se muestran estadísticas descriptivas, gráficos de distribución y de relación con la variable objetivo (si aplica). Además, se describen posibles transformaciones que se pueden aplicar a la variable

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 8)
sns.countplot(x = 'age', data = df)
ax.set_xlabel('Age', fontsize=15)
ax.set_ylabel('Count', fontsize=15)
ax.set_title('Age Count Distribution', fontsize=15)
sns.despine()

# %%
indep_variables = df.select_dtypes('object')
indep_variables = [x for x in indep_variables.columns if x != 'y']

# %%
for col in indep_variables:
    counts = df[col].value_counts().sort_index()
    if len(counts) > 10:
      fig = plt.figure(figsize=(30, 10))
    else:
      fig = plt.figure(figsize=(9, 6))
    ax = fig.gca()
    counts.plot.bar(ax = ax, color='steelblue')
    ax.set_title(col + ' counts')
    ax.set_xlabel(col) 
    ax.set_ylabel("Frequency")
plt.show()

# %% [markdown]
# Las variables categoricas serán transformadas utilizando alguna representación numerica. Puede ser one hot encoding o label encondig.
#
# Adicionalmente, se transformará la edad para dejarla como un rango, es decir. si la persona tiene 46 años solo se tomará el primer digito siendo 4; si la persona tiene 29 años se tomara el 2.

# %% [markdown]
# ## Ranking de variables
#
# En esta sección se presenta un ranking de las variables más importantes para predecir la variable objetivo. Se utilizan técnicas como la correlación, el análisis de componentes principales (PCA) o la importancia de las variables en un modelo de aprendizaje automático.

# %%
corr = df.corr()
plt.figure(figsize=(12,8))
sns.heatmap(corr, cmap="Reds", annot = True);
# Out:
# <ipython-input-52-81088cfcab92>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()

# %% [markdown]
# Aquí se puede ver cierta correlación entre emp. var rate y nr.employed. Igualmente con euribor3m y emp.var rate.
